# %% [markdown]
# # Pandas essentials
#
# - hide: true
# - sticky_rank: 1
# - toc: true
# - comments: true
# - categories: [python, pandas]

# %%
from imports import *

# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload
# %autoreload 2

# %%
df = pd.read_parquet(SAMPLEDATA)
print(df.shape)
df.head(3)
# Out:
# (157287, 22)
#    user_id transaction_date  amount  \
# 0      777       2012-01-03    3.03
# 1      777       2012-01-03    6.68
# 2      777       2012-01-03   10.27
#
#                                          transaction_description  \
# 0                                                 aviva pa - d/d
# 1         9572 31dec11 , tesco stores 3345 , warrington gb - pos
# 2  9572 30dec11 , mcdonalds , restaurant , winwick road gb - pos
#
#   merchant_name                         tag gender  \
# 0         aviva              life insurance      m
# 1         tesco  food, groceries, household      m
# 2     mcdonalds         dining and drinking      m
#
#                        up_tag  account_id  year_of_birth  \
# 0              life insurance      262916         1969.0
# 1  food, groceries, household      262916         1969.0
# 2         dining and drinking      262916         1969.0
#
#   merchant_business_line salary_range  latest_balance account_type  \
# 0                  aviva   20k to 30k          364.22      current
# 1      tesco supermarket   20k to 30k          364.22      current
# 2              mcdonalds   20k to 30k          364.22      current
#
#   credit_debit  transaction_id          bank postcode      ym account_created  \
# 0        debit          688262  natwest bank    wa1 4  201201      2011-07-20
# 1        debit          688263  natwest bank    wa1 4  201201      2011-07-20
# 2        debit          688264  natwest bank    wa1 4  201201      2011-07-20
#
#   user_registration_date account_last_refreshed
# 0             2011-07-20    2020-07-21 20:32:00
# 1             2011-07-20    2020-07-21 20:32:00
# 2             2011-07-20    2020-07-21 20:32:00

# %%
df.iloc[0, 0] = np.nan
df.dropna()
# Out:
#          user_id transaction_date  amount  \
# 1          777.0       2012-01-03    6.68
# 2          777.0       2012-01-03   10.27
# 3          777.0       2012-01-03   12.00
# 4          777.0       2012-01-03  400.00
# 5          777.0       2012-01-04    8.74
# ...          ...              ...     ...
# 157282  579777.0       2020-07-01   85.00
# 157283  579777.0       2020-07-01  474.54
# 157284  579777.0       2020-07-01  750.00
# 157285  579777.0       2020-07-02  -27.98
# 157286  579777.0       2020-07-02   60.00
#
#                                               transaction_description  \
# 1              9572 31dec11 , tesco stores 3345 , warrington gb - pos
# 2       9572 30dec11 , mcdonalds , restaurant , winwick road gb - pos
# 3              9572 31dec11 , tesco stores 3345 , warrington gb - pos
# 4                                                  <mdbremoved> - s/o
# 5                    9572 03jan12 , tesco-stores sacat, sale gb - pos
# ...                                                               ...
# 157282                                                   <mdbremoved>
# 157283                                                        halifax
# 157284                                                   <mdbremoved>
# 157285                                   payment received - thank you
# 157286                                                    bulb energy
#
#        merchant_name                         tag gender  \
# 1              tesco  food, groceries, household      m
# 2          mcdonalds         dining and drinking      m
# 3              tesco  food, groceries, household      m
# 4        no merchant               other account      m
# 5              tesco  food, groceries, household      m
# ...              ...                         ...    ...
# 157282   no merchant                   transfers      m
# 157283       halifax               personal loan      m
# 157284   no merchant                   transfers      m
# 157285   no merchant                 credit card      m
# 157286   no merchant   energy - gas, elec, other      m
#
#                             up_tag  account_id  year_of_birth  \
# 1       food, groceries, household      262916         1969.0
# 2              dining and drinking      262916         1969.0
# 3       food, groceries, household      262916         1969.0
# 4                    other account      262916         1969.0
# 5       food, groceries, household      262916         1969.0
# ...                            ...         ...            ...
# 157282                   transfers     1655945         1986.0
# 157283               personal loan     1655945         1986.0
# 157284                   transfers     1655945         1986.0
# 157285                 credit card     1655946         1986.0
# 157286   energy - gas, elec, other     1655945         1986.0
#
#            merchant_business_line salary_range  latest_balance account_type  \
# 1               tesco supermarket   20k to 30k          364.22      current
# 2                       mcdonalds   20k to 30k          364.22      current
# 3               tesco supermarket   20k to 30k          364.22      current
# 4                non merchant mbl   20k to 30k          364.22      current
# 5               tesco supermarket   20k to 30k          364.22      current
# ...                           ...          ...             ...          ...
# 157282           non merchant mbl   20k to 30k         6684.43      current
# 157283                    halifax   20k to 30k         6684.43      current
# 157284           non merchant mbl   20k to 30k         6684.43      current
# 157285           account provider   20k to 30k          -30.80  credit card
# 157286  no merchant business line   20k to 30k         6684.43      current
#
#        credit_debit  transaction_id                      bank postcode  \
# 1             debit          688263              natwest bank    wa1 4
# 2             debit          688264              natwest bank    wa1 4
# 3             debit          688265              natwest bank    wa1 4
# 4             debit          688261              natwest bank    wa1 4
# 5             debit          688267              natwest bank    wa1 4
# ...             ...             ...                       ...      ...
# 157282        debit       793743159  halifax personal banking     m4 6
# 157283        debit       793743154  halifax personal banking     m4 6
# 157284        debit       793743157  halifax personal banking     m4 6
# 157285       credit       794507339  halifax personal banking     m4 6
# 157286        debit       794296457  halifax personal banking     m4 6
#
#             ym account_created user_registration_date account_last_refreshed
# 1       201201      2011-07-20             2011-07-20    2020-07-21 20:32:00
# 2       201201      2011-07-20             2011-07-20    2020-07-21 20:32:00
# 3       201201      2011-07-20             2011-07-20    2020-07-21 20:32:00
# 4       201201      2011-07-20             2011-07-20    2020-07-21 20:32:00
# 5       201201      2011-07-20             2011-07-20    2020-07-21 20:32:00
# ...        ...             ...                    ...                    ...
# 157282  202007      2020-04-07             2020-04-07    2020-07-05 06:34:00
# 157283  202007      2020-04-07             2020-04-07    2020-07-05 06:34:00
# 157284  202007      2020-04-07             2020-04-07    2020-07-05 06:34:00
# 157285  202007      2020-04-07             2020-04-07    2020-07-05 06:34:00
# 157286  202007      2020-04-07             2020-04-07    2020-07-05 06:34:00
#
# [26490 rows x 22 columns]

# %% [markdown]
# ## Questions

# %% [markdown]
# ## True of False

# %% [markdown]
# ## Fluency exercises

# %% [markdown]
# ## Topics

# %% [markdown]
# #### Groupby

# %% [markdown]
# Create a dictionary from groups based on column types:

# %%
df = sns.load_dataset('iris')
pieces = dict(list(df.groupby('species')))
pieces['setosa'][:3]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
df.dtypes

# %% [markdown]
# ## Topics

# %% [markdown]
# ## Sources
#
# - [Fluent Python](https://www.oreilly.com/library/view/fluent-python/9781491946237/)
# - [Python Cookbook](https://www.oreilly.com/library/view/python-cookbook-3rd/9781449357337/)
# - [Learning Python](https://www.oreilly.com/library/view/learning-python-5th/9781449355722/)
# - [The Hitchhiker's Guide to Python](https://docs.python-guide.org/writing/structure/)
# - [Effective Python](https://effectivepython.com)
# - [Python for Data Analysis](https://www.oreilly.com/library/view/python-for-data/9781491957653/)
# - [Python Data Science Handbook](https://www.oreilly.com/library/view/python-data-science/9781491912126/)
